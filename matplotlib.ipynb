# %% [markdown]
# # Matplotlib

# %% [markdown]
# Installation of matplotlib
#
# conda install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Plots, Axes, labels, legends

# %%
x_axis_values = np.linspace(1, 10, 20)
x_axis_values
# Out:
# array([  1.        ,   1.47368421,   1.94736842,   2.42105263,
#          2.89473684,   3.36842105,   3.84210526,   4.31578947,
#          4.78947368,   5.26315789,   5.73684211,   6.21052632,
#          6.68421053,   7.15789474,   7.63157895,   8.10526316,
#          8.57894737,   9.05263158,   9.52631579,  10.        ])

# %%
y_axis_values = np.log(x_axis_values)
y_axis_values
# Out:
# array([ 0.        ,  0.38776553,  0.66647893,  0.88420242,  1.06289421,
#         1.2144441 ,  1.34602046,  1.46228027,  1.56642053,  1.66073121,
#         1.7469089 ,  1.82624565,  1.89974811,  1.96821591,  2.03229476,
#         2.09251362,  2.14931122,  2.2030555 ,  2.25405805,  2.30258509])

# %%
# Line plot

plt.plot(x_axis_values, y_axis_values, 'blue')
plt.xlabel('X Axis Values')
plt.ylabel('Y Axis Values')
plt.title('Basic plot')
plt.show()

# %%
# When we are running analysis, we might want to compare results.
# For that we might need to have the plots placed side by side.

# Pyplot API provides subplot as an option.
plt.subplot(121)    # plt.subplot(nrows, ncols, plot_number)
plt.plot(x_axis_values, y_axis_values, 'blue')

plt.subplot(122)
plt.plot(x_axis_values, np.power(x_axis_values,2) , 'green');

# %% [markdown]
# So whatever we were seeing was the pyplot module API.
#
# This API is good for quick plots, but Matplotlib recommends using object-oriented API as it provides more control and customization for the plots.
#
# Most of these functions also exist as methods in the matplotlib.axes.Axes class.
#
# Introduction to the Object Oriented Method
#
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:
#
# So let us get started.

# %%
fig, ax = plt.subplots()   # plt.subplots is equivalent to using fig = plt.figure() and then ax = fig.add_subplot(111)

ax.plot(x_axis_values, y_axis_values, 'blue')
ax.set_xlabel('X Axis Values') # Notice the use of set_ to begin methods
ax.set_ylabel('Y Axis Values')
ax.set_title('Set Title')
# Out:
# Text(0.5,1,'Set Title')

# %%
# Creates two subplots

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x_axis_values, y_axis_values)
ax1.set_title('Sharing Y axis')
ax2.scatter(x_axis_values, y_axis_values)

# %%
# There are instances when we would have multiple lines in the same plot.

fig, ax = plt.subplots()
ax.plot(x_axis_values, np.power(x_axis_values,2), label="Square")
ax.plot(x_axis_values, np.power(x_axis_values,3), label="Cube")
ax.legend()  # Legend identify the line.

# %%
# Scatter plots

plt.scatter(x_axis_values, y_axis_values)

data_norm_dist = np.random.normal(0,100,100000)

# %%
plt.hist(data_norm_dist, bins=100)
# Out:
# (array([  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           2.00000000e+00,   6.00000000e+00,   6.00000000e+00,
#           4.00000000e+00,   8.00000000e+00,   6.00000000e+00,
#           8.00000000e+00,   2.40000000e+01,   2.00000000e+01,
#           3.70000000e+01,   3.20000000e+01,   5.60000000e+01,
#           5.40000000e+01,   8.20000000e+01,   9.30000000e+01,
#           1.43000000e+02,   1.74000000e+02,   2.07000000e+02,
#           2.72000000e+02,   3.21000000e+02,   3.48000000e+02,
#           4.57000000e+02,   5.72000000e+02,   6.28000000e+02,
#           7.49000000e+02,   8.80000000e+02,   9.72000000e+02,
#           1.19500000e+03,   1.32100000e+03,   1.46700000e+03,
#           1.70100000e+03,   1.86100000e+03,   1.96000000e+03,
#           2.26500000e+03,   2.43700000e+03,   2.66600000e+03,
#           2.76100000e+03,   2.92700000e+03,   3.17200000e+03,
#           3.35600000e+03,   3.36200000e+03,   3.39400000e+03,
#           3.56300000e+03,   3.55300000e+03,   3.65700000e+03,
#           3.48500000e+03,   3.47800000e+03,   3.44900000e+03,
#           3.34900000e+03,   3.19800000e+03,   3.04200000e+03,
#           2.88300000e+03,   2.65000000e+03,   2.58600000e+03,
#           2.39500000e+03,   2.17100000e+03,   1.93400000e+03,
#           1.71500000e+03,   1.54600000e+03,   1.42000000e+03,
#           1.27200000e+03,   1.05200000e+03,   9.38000000e+02,
#           8.37000000e+02,   7.00000000e+02,   5.65000000e+02,
#           4.87000000e+02,   4.21000000e+02,   3.32000000e+02,
#           2.86000000e+02,   2.40000000e+02,   1.55000000e+02,
#           1.45000000e+02,   1.09000000e+02,   8.70000000e+01,
#           6.70000000e+01,   5.00000000e+01,   4.90000000e+01,
#           3.20000000e+01,   2.40000000e+01,   2.20000000e+01,
#           1.50000000e+01,   8.00000000e+00,   1.00000000e+01,
#           7.00000000e+00,   0.00000000e+00,   5.00000000e+00,
#           1.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([-448.21538061, -439.29396779, -430.37255498, -421.45114217,
#         -412.52972936, -403.60831654, -394.68690373, -385.76549092,
#         -376.84407811, -367.92266529, -359.00125248, -350.07983967,
#         -341.15842685, -332.23701404, -323.31560123, -314.39418842,
#         -305.4727756 , -296.55136279, -287.62994998, -278.70853717,
#         -269.78712435, -260.86571154, -251.94429873, -243.02288592,
#         -234.1014731 , -225.18006029, -216.25864748, -207.33723466,
#         -198.41582185, -189.49440904, -180.57299623, -171.65158341,
#         -162.7301706 , -153.80875779, -144.88734498, -135.96593216,
#         -127.04451935, -118.12310654, -109.20169373, -100.28028091,
#          -91.3588681 ,  -82.43745529,  -73.51604248,  -64.59462966,
#          -55.67321685,  -46.75180404,  -37.83039122,  -28.90897841,
#          -19.9875656 ,  -11.06615279,   -2.14473997,    6.77667284,
#           15.69808565,   24.61949846,   33.54091128,   42.46232409,
#           51.3837369 ,   60.30514971,   69.22656253,   78.14797534,
#           87.06938815,   95.99080097,  104.91221378,  113.83362659,
#          122.7550394 ,  131.67645222,  140.59786503,  149.51927784,
#          158.44069065,  167.36210347,  176.28351628,  185.20492909,
#          194.1263419 ,  203.04775472,  211.96916753,  220.89058034,
#          229.81199315,  238.73340597,  247.65481878,  256.57623159,
#          265.49764441,  274.41905722,  283.34047003,  292.26188284,
#          301.18329566,  310.10470847,  319.02612128,  327.94753409,
#          336.86894691,  345.79035972,  354.71177253,  363.63318534,
#          372.55459816,  381.47601097,  390.39742378,  399.3188366 ,
#          408.24024941,  417.16166222,  426.08307503,  435.00448785,
#          443.92590066]),
#  <a list of 100 Patch objects>)

# %%
# Box Plot

box_data = [np.random.normal(0, std, 100) for std in range(1, 4)]  # List comprehension
box_data

# rectangular box plot
plt.boxplot(box_data,vert=True,patch_artist=True);
